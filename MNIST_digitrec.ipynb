# %% [markdown]
# <a href="https://colab.research.google.com/github/DevD231204/DevD231204/blob/main/MNIST_digitrec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

model = Sequential([
    Input(shape=(28,28,1)),
    Conv2D(32, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
import numpy as np

# Load data
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values (0-255 to 0-1)
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Reshape for CNN input (28x28x1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

# Labels are integers (0–9), no need for one-hot encoding if using sparse_categorical_crossentropy
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train,
                    epochs=10, batch_size=64,
                    validation_split=0.1)
# Out:
# Epoch 1/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 74s 84ms/step - accuracy: 0.8598 - loss: 0.4628 - val_accuracy: 0.9852 - val_loss: 0.0501
# Epoch 2/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 72s 85ms/step - accuracy: 0.9699 - loss: 0.1044 - val_accuracy: 0.9863 - val_loss: 0.0563
# Epoch 3/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 73s 86ms/step - accuracy: 0.9775 - loss: 0.0789 - val_accuracy: 0.9903 - val_loss: 0.0390
# Epoch 4/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 77s 81ms/step - accuracy: 0.9829 - loss: 0.0553 - val_accuracy: 0.9892 - val_loss: 0.0390
# Epoch 5/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 69s 81ms/step - accuracy: 0.9837 - loss: 0.0549 - val_accuracy: 0.9918 - val_loss: 0.0410
# Epoch 6/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 84s 84ms/step - accuracy: 0.9874 - loss: 0.0404 - val_accuracy: 0.9898 - val_loss: 0.0427
# Epoch 7/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 84s 87ms/step - accuracy: 0.9873 - loss: 0.0429 - val_accuracy: 0.9863 - val_loss: 0.0589
# Epoch 8/10
# ...

# %%
import numpy as np
preds = model.predict(x_test)               # probabilities for each class
predicted_labels = np.argmax(preds, axis=1) # pick highest-probability digit
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step

# %%
# Evaluate the model on the test dataset
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9907 - loss: 0.0348
# Test Accuracy: 99.21%
